# %% [markdown]
# ### `Loading libraries`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### `Fetching Dataset using pandas`

# %%
df = pd.read_csv("nykaa_campaign_data.csv")
df.head(3)
# Out:
#    Campaign_ID Campaign_Type        Target_Audience  Duration  \
# 0  NY-CMP-1000  Social Media       College Students        21
# 1  NY-CMP-1001      Paid Ads  Tier 2 City Customers        18
# 2  NY-CMP-1002    Influencer                  Youth        23
#
#                 Channel_Used  Impressions  Clicks  Leads  Conversions  \
# 0          WhatsApp, YouTube        57804    6156   3616         2355
# 1                    YouTube        91801    3321   1971         1357
# 2  WhatsApp, Google, YouTube        15536    2182    952          755
#
#    Revenue  Acquisition_Cost   ROI Language  Engagement_Score  \
# 0  1867515            111.03  6.14    Hindi             20.98
# 1  1046247            180.83  3.26    Hindi              7.24
# 2   197055             90.60  1.88  English             25.03
#
#    Customer_Segment        Date
# 0  College Students  29-04-2025
# 1  College Students  06-04-2025
# 2  College Students  14-01-2025

# %% [markdown]
# ### `Data inspection`

# %%
# Checking shape of the dataset.
print(f"Shape of the dataset:\nRows are {df.shape[0]}, Columnns are {df.shape[1]}")
# Out:
# Shape of the dataset:
# Rows are 55555, Columnns are 16

# %%
# checking size of the dataset.
print('Size of the dataset is:',df.size)
# Out:
# Size of the dataset is: 888880

# %%
# Checking memory usage by the dataset.
df.memory_usage(deep = True).sum()/1024**2
# Out:
# np.float64(26.23383903503418)

# %% [markdown]
# ```
# The memory usage is high and can be optimised by converting datatypes which we will do in the following process so that machine work efficiently.
# ```

# %%
# Understanding data types of the features.
df.dtypes
# Out:
# Campaign_ID             str
# Campaign_Type           str
# Target_Audience         str
# Duration              int64
# Channel_Used            str
# Impressions           int64
# Clicks                int64
# Leads                 int64
# Conversions           int64
# Revenue               int64
# Acquisition_Cost    float64
# ROI                 float64
# Language                str
# Engagement_Score    float64
# Customer_Segment        str
# Date                    str
# dtype: object

# %% [markdown]
# ```
# Data type is str in many features which is redundant and may consume large memory which may also reduce the machine speed during data processing. Thus we will change data type of required features from str to category so that we can optimise memory usage.
# ```

# %% [markdown]
# ### `Data preparation and preprocessing`

# %%
# Understanding data type and the max values of the numerical features so that we can change the
# data types of the features as per their ranges optimize memory usage.
print(f"{'Column':20} | {'dtype':15} | {'Max Value':15}")
print("-"*50)
for i in df.select_dtypes(include = [np.number]).columns:
    print(f"{i:20} | {str(df[i].dtype):15} | {df[i].max():8.2f}")
# Out:
# Column               | dtype           | Max Value
# --------------------------------------------------
# Duration             | int64           |    30.00
# Impressions          | int64           | 100000.00
# Clicks               | int64           | 14868.00
# Leads                | int64           |  8876.00
# Conversions          | int64           |  6686.00
# Revenue              | int64           | 4579910.00
# Acquisition_Cost     | float64         | 15473.16
# ROI                  | float64         |    74.42
# Engagement_Score     | float64         |    30.91

# %%
# changing data types of the features to reduce memory usage.
df = df.astype(
    {"Campaign_Type": "category",
     "Target_Audience": "category",
     "Language": "category",
     "Customer_Segment": "category",
     "Duration": "int8",
     "Clicks": "int16",
     "Leads": "int16",
     "Conversions": "int16",
     "Acquisition_Cost": "float32",
     "ROI": "float16",
     "Engagement_Score": "float16"
     
     })

# %%
# Changing "Date" column from str to datetime format.
df["Date"] = pd.to_datetime(df["Date"], format = "%d-%m-%Y")

# %%
# Recalculating the memory usage after changing the data types of the features.
df.memory_usage(deep = True).sum()/1024**2
# Out:
# np.float64(8.962231636047363)

# %% [markdown]
# ```
# Now, we can clearly see that after allocating data types to the columns as per their need, the size of the memory usage has requced significanlty from 26 MB to almost 11 MB. This optimisation of the memory usage will enhace the machine processing.
# ```

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 55555 entries, 0 to 55554
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Campaign_ID       55555 non-null  str
#  1   Campaign_Type     55555 non-null  category
#  2   Target_Audience   55555 non-null  category
#  3   Duration          55555 non-null  int8
#  4   Channel_Used      55555 non-null  str
#  5   Impressions       55555 non-null  int64
#  6   Clicks            55555 non-null  int16
#  7   Leads             55555 non-null  int16
#  8   Conversions       55555 non-null  int16
#  9   Revenue           55555 non-null  int64
#  10  Acquisition_Cost  55555 non-null  float32
#  11  ROI               55555 non-null  float16
#  12  Language          55555 non-null  category
#  13  Engagement_Score  55555 non-null  float16
#  14  Customer_Segment  55555 non-null  category
#  15  Date              55555 non-null  datetime64[us]
# dtypes: category(4), datetime64[us](1), float16(2), float32(1), int16(3), int64(2), int8(1), str(2)
# memory usage: 3.1 MB

# %%
# Checking for missing values in the dataset.
df.isnull().sum()
# Out:
# Campaign_ID         0
# Campaign_Type       0
# Target_Audience     0
# Duration            0
# Channel_Used        0
# Impressions         0
# Clicks              0
# Leads               0
# Conversions         0
# Revenue             0
# Acquisition_Cost    0
# ROI                 0
# Language            0
# Engagement_Score    0
# Customer_Segment    0
# Date                0
# dtype: int64

# %%
# Checking for duplicate records in the dataset.
df.duplicated().sum()
# Out:
# np.int64(0)
